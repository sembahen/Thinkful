# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
recipe_df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/epi_r.csv')

# %%
recipe_df.head()
# Out:
#                                          title  rating  ...  snack week  turkey
# 0              Lentil, Apple, and Turkey Wrap    2.500  ...         0.0     1.0
# 1  Boudin Blanc Terrine with Red Onion Confit    4.375  ...         0.0     0.0
# 2                Potato and Fennel Soup Hodge    3.750  ...         0.0     0.0
# 3             Mahi-Mahi in Tomato Olive Sauce    5.000  ...         0.0     0.0
# 4                    Spinach Noodle Casserole    3.125  ...         0.0     0.0
#
# [5 rows x 680 columns]

# %%
print(recipe_df.shape)
# Attempt to drop all rows with null and retain the dietary information (calories, protein, fat, sodium)
recipe_df2=recipe_df.dropna(axis=0)
print(recipe_df2.shape)
# Out:
# (20052, 680)
# (15864, 680)

# %%
# we lost 5,000 rows. If the dietary information is very useful, am ok with the loss

# %%
#Next step is convert it into a classification problem. 
recipe_df2.rating.describe()
# Out:
# count    15864.000000
# mean         3.760952
# std          1.285518
# min          0.000000
# 25%          3.750000
# 50%          4.375000
# 75%          4.375000
# max          5.000000
# Name: rating, dtype: float64

# %%
# We shall say all ratings abobe 4.3 are "High" and all ratings below that are "Low"

# %%
recipe_df2["rating"].unique
# Out:
# <bound method Series.unique of 0        2.500
# 1        4.375
# 2        3.750
# 4        3.125
# 5        4.375
#          ...
# 20047    3.125
# 20048    4.375
# 20049    4.375
# 20050    4.375
# 20051    4.375
# Name: rating, Length: 15864, dtype: float64>

# %%
#X["rating"]=np.where(X["rating"]>4.3,"High","Low")

# %%
 recipe_df2['rating_categorized'] = recipe_df2['rating'].apply(lambda row: "High" if row>4.3 else "Low")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
recipe_df2['rating'].value_counts()
# Out:
# 4.375    6552
# 3.750    4136
# 5.000    2106
# 0.000    1296
# 3.125    1165
# 2.500     405
# 1.250     123
# 1.875      81
# Name: rating, dtype: int64

# %%
recipe_df2['rating_categorized']
# Out:
# 0         Low
# 1        High
# 2         Low
# 4         Low
# 5        High
#          ...
# 20047     Low
# 20048    High
# 20049    High
# 20050    High
# 20051    High
# Name: rating_categorized, Length: 15864, dtype: object

# %%
recipe_df2.shape
# Out:
# (15864, 681)

# %%
recipe_df2['rating_categorized'].value_counts()
# Out:
# High    8658
# Low     7206
# Name: rating_categorized, dtype: int64

# %%
#Drop non-numeric columns
recipe_df3=recipe_df2.select_dtypes(include=[np.number])
recipe_df3
# Out:
#        rating  calories  protein   fat  ...  leftovers  snack  snack week  turkey
# 0       2.500     426.0     30.0   7.0  ...        0.0    0.0         0.0     1.0
# 1       4.375     403.0     18.0  23.0  ...        0.0    0.0         0.0     0.0
# 2       3.750     165.0      6.0   7.0  ...        0.0    0.0         0.0     0.0
# 4       3.125     547.0     20.0  32.0  ...        0.0    0.0         0.0     0.0
# 5       4.375     948.0     19.0  79.0  ...        0.0    0.0         0.0     0.0
# ...       ...       ...      ...   ...  ...        ...    ...         ...     ...
# 20047   3.125      28.0      2.0   2.0  ...        0.0    0.0         0.0     0.0
# 20048   4.375     671.0     22.0  28.0  ...        0.0    0.0         0.0     0.0
# 20049   4.375     563.0     31.0  38.0  ...        0.0    0.0         0.0     1.0
# 20050   4.375     631.0     45.0  24.0  ...        0.0    0.0         0.0     0.0
# ...

# %%
from sklearn.svm import SVC
svr = SVC()
X = recipe_df3
#X = recipe_df3.drop(['rating',"rating_categorized"]).sample(frac=0.3, replace=True, random_state=1)
Y = recipe_df2["rating_categorized"]
svc = SVC(kernel = "rbf")
svc.fit(X,Y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(X.shape)
print(Y.shape)

# %%
Y.value_counts()
# Out:
# 4.375    6552
# 3.750    4136
# 5.000    2106
# 0.000    1296
# 3.125    1165
# 2.500     405
# 1.250     123
# 1.875      81
# Name: rating, dtype: int64

# %%
svc.score(X, Y)
# Out:
# 0.5458900655572365

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svr, X, Y, cv=5)
# Out:
# array([0.5455405 , 0.54585566, 0.54585566, 0.54585566, 0.54571248])

# %%
#definitely better prediction than the regression model
