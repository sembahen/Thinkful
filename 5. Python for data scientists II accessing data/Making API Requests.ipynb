# %%
import requests
#query={'culture':'British'}
url='https://api.harvardartmuseums.org/person?q=culture:British&apikey=89598bd0-418e-11ea-a78a-b9f15528a9c1'
response=requests.get(url,params=None)
data=response.json()
for info in data['records']:
  print("Name: {}     Birthplace: {}".format(info["displayname"], info["birthplace"]))
# Out:
# Name: Rackstraw Downes     Birthplace: Kent, England
# Name: James Gamble     Birthplace: None
# Name: Peter Hutchinson     Birthplace: London, England
# Name: Edward Burch Jr.     Birthplace: None
# Name: William James Bennett     Birthplace: None
# Name: Thomas Farren     Birthplace: Tewksbury
# Name: W. Turnbull     Birthplace: None
# Name: Alexander Bassano     Birthplace: Italy
# Name: C. Greenwood     Birthplace: None
# Name: Read & Co     Birthplace: None
