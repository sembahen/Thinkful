# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.18.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)

# %% [markdown]
# 1. Load the dataset and make your preprocessing like normalizing the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import time
from sklearn.manifold import TSNE

# %%
# We load the MNIST dataset below
mnist = fetch_openml('mnist_784', version=1, cache=True)

# %%
np.random.seed(123)

indices = np.random.choice(70000,10000)
X = mnist.data[indices] / 255.0
y = mnist.target[indices]

print(X.shape, y.shape)
# Out:
# (10000, 784) (10000,)

# %% [markdown]
# 2. Apply t-SNE to the data by setting n_components=2.

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 1.489s...
# [t-SNE] Computed neighbors for 10000 samples in 179.653s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.182897
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.249031
# [t-SNE] KL divergence after 300 iterations: 2.809339
# t-SNE done! Time elapsed: 209.08214473724365 seconds

# %% [markdown]
# 3. Using the two-dimensional t-SNE representation, draw a graph of the data by coloring and labeling the data points as we did in the checkpoint.

# %%
plt.figure(figsize=(10,5))
colours = ["r","b","g","c","m","y","k","r","burlywood","chartreuse"]
for i in range(tsne_results.shape[0]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], str(y[i]),
             color=colours[int(y[i])],
             fontdict={'weight': 'bold', 'size': 50}
        )

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# 4. Do you think t-SNE solution is satisfactory? Can you distinguish between different classes easily? Which one has done a better job: t-SNE or the PCA you applied in the assignment of the previous checkpoint?

# %%
plt.figure(figsize=(10,5))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
#yes t-SNE did a better job than PCA

# %% [markdown]
# 5. Now, play with the different perplexity values and apply t-SNE for each of them. Which perplexity value is the best one in terms of the two-dimensional representation clarity?

# %%
for x in [10, 20, 50, 100]:
  tsne = TSNE(n_components=2, verbose=1, perplexity=x, n_iter=300)
  tsne_results = tsne.fit_transform(X)

  plt.figure(figsize=(10,5))
  plt.title("t-SNE with perplexity= {}".format(x))
  plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
  plt.xticks([])
  plt.yticks([])
  plt.axis('off')
  plt.show()
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 1.472s...
# [t-SNE] Computed neighbors for 10000 samples in 178.684s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.697200
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 93.371674
# [t-SNE] KL divergence after 300 iterations: 3.705007
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 1.286s...
# [t-SNE] Computed neighbors for 10000 samples in 178.697s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.949176
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.258530
# [t-SNE] KL divergence after 300 iterations: 3.271059
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 1.333s...
# [t-SNE] Computed neighbors for 10000 samples in 179.888s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.257154
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.774025
# [t-SNE] KL divergence after 300 iterations: 2.674031
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 1.292s...
# [t-SNE] Computed neighbors for 10000 samples in 180.500s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.490839
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.603104
# [t-SNE] KL divergence after 300 iterations: 2.247672

# %%
# its hard to tell which one is better but all the configurations are better than PCA
