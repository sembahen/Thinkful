# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
from sklearn import tree
from IPython.display import Image
import pydotplus
import graphviz
# %matplotlib inline

# %%
df = pd.read_csv((
    "https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/"
    "master/ESS_practice_data/ESSdata_Thinkful.csv")).dropna()

# %%
df
# Out:
#      cntry    idno  year  tvtot  ppltrst  ...  sclmeet  sclact  gndr  agea  partner
# 0       CH     5.0     6    3.0      3.0  ...      5.0     4.0   2.0  60.0      1.0
# 1       CH    25.0     6    6.0      5.0  ...      3.0     2.0   2.0  59.0      1.0
# 2       CH    26.0     6    1.0      8.0  ...      6.0     3.0   1.0  24.0      2.0
# 3       CH    28.0     6    4.0      6.0  ...      6.0     2.0   2.0  64.0      1.0
# 4       CH    29.0     6    5.0      6.0  ...      7.0     2.0   2.0  55.0      1.0
# ...    ...     ...   ...    ...      ...  ...      ...     ...   ...   ...      ...
# 8589    SE  3729.0     7    3.0      4.0  ...      6.0     2.0   1.0  18.0      2.0
# 8590    SE  3732.0     7    5.0      6.0  ...      6.0     3.0   1.0  15.0      2.0
# 8591    SE  3743.0     7    4.0      5.0  ...      6.0     3.0   1.0  44.0      2.0
# 8592    SE  3744.0     7    5.0      8.0  ...      7.0     3.0   1.0  15.0      2.0
# 8593    SE  3746.0     7    2.0      6.0  ...      7.0     4.0   2.0  15.0      2.0
#
# [8147 rows x 13 columns]

# %%
y = df['happy']
X = df.loc[:, ~df.columns.isin(['happy', 'cntry'])]

# %%
X
# Out:
#         idno  year  tvtot  ppltrst  ...  sclact  gndr  agea  partner
# 0        5.0     6    3.0      3.0  ...     4.0   2.0  60.0      1.0
# 1       25.0     6    6.0      5.0  ...     2.0   2.0  59.0      1.0
# 2       26.0     6    1.0      8.0  ...     3.0   1.0  24.0      2.0
# 3       28.0     6    4.0      6.0  ...     2.0   2.0  64.0      1.0
# 4       29.0     6    5.0      6.0  ...     2.0   2.0  55.0      1.0
# ...      ...   ...    ...      ...  ...     ...   ...   ...      ...
# 8589  3729.0     7    3.0      4.0  ...     2.0   1.0  18.0      2.0
# 8590  3732.0     7    5.0      6.0  ...     3.0   1.0  15.0      2.0
# 8591  3743.0     7    4.0      5.0  ...     3.0   1.0  44.0      2.0
# 8592  3744.0     7    5.0      8.0  ...     3.0   1.0  15.0      2.0
# 8593  3746.0     7    2.0      6.0  ...     4.0   2.0  15.0      2.0
#
# [8147 rows x 11 columns]

# %%
X = pd.concat([X, pd.get_dummies(df['cntry'])], axis=1)

# %%
X
# Out:
#         idno  year  tvtot  ppltrst  pplfair  pplhlp  ...  CH  CZ  DE  ES  NO  SE
# 0        5.0     6    3.0      3.0     10.0     5.0  ...   1   0   0   0   0   0
# 1       25.0     6    6.0      5.0      7.0     5.0  ...   1   0   0   0   0   0
# 2       26.0     6    1.0      8.0      8.0     8.0  ...   1   0   0   0   0   0
# 3       28.0     6    4.0      6.0      6.0     7.0  ...   1   0   0   0   0   0
# 4       29.0     6    5.0      6.0      7.0     5.0  ...   1   0   0   0   0   0
# ...      ...   ...    ...      ...      ...     ...  ...  ..  ..  ..  ..  ..  ..
# 8589  3729.0     7    3.0      4.0      5.0     3.0  ...   0   0   0   0   0   1
# 8590  3732.0     7    5.0      6.0      4.0     4.0  ...   0   0   0   0   0   1
# 8591  3743.0     7    4.0      5.0      7.0     6.0  ...   0   0   0   0   0   1
# 8592  3744.0     7    5.0      8.0      8.0     6.0  ...   0   0   0   0   0   1
# 8593  3746.0     7    2.0      6.0      7.0     5.0  ...   0   0   0   0   0   1
#
# [8147 rows x 17 columns]

# %%
df = pd.read_csv((
    "https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/"
    "master/ESS_practice_data/ESSdata_Thinkful.csv")).dropna()

# %%
df
# Out:
#      cntry    idno  year  tvtot  ppltrst  ...  sclmeet  sclact  gndr  agea  partner
# 0       CH     5.0     6    3.0      3.0  ...      5.0     4.0   2.0  60.0      1.0
# 1       CH    25.0     6    6.0      5.0  ...      3.0     2.0   2.0  59.0      1.0
# 2       CH    26.0     6    1.0      8.0  ...      6.0     3.0   1.0  24.0      2.0
# 3       CH    28.0     6    4.0      6.0  ...      6.0     2.0   2.0  64.0      1.0
# 4       CH    29.0     6    5.0      6.0  ...      7.0     2.0   2.0  55.0      1.0
# ...    ...     ...   ...    ...      ...  ...      ...     ...   ...   ...      ...
# 8589    SE  3729.0     7    3.0      4.0  ...      6.0     2.0   1.0  18.0      2.0
# 8590    SE  3732.0     7    5.0      6.0  ...      6.0     3.0   1.0  15.0      2.0
# 8591    SE  3743.0     7    4.0      5.0  ...      6.0     3.0   1.0  44.0      2.0
# 8592    SE  3744.0     7    5.0      8.0  ...      7.0     3.0   1.0  15.0      2.0
# 8593    SE  3746.0     7    2.0      6.0  ...      7.0     4.0   2.0  15.0      2.0
#
# [8147 rows x 13 columns]

# %%
y = df['partner']  
X = df.loc[:, ~df.columns.isin(['partner', 'cntry', 'idno'])]

# Make the categorical variable 'country' into dummies.
X = pd.concat([X, pd.get_dummies(df['cntry'])], axis=1)

# Create training and test sets.
offset = int(X.shape[0] * 0.8)

# %%
offset
# Out:
# 6517

# %%
X.shape
# Out:
# (8147, 16)

# %%
X.shape[0]
# Out:
# 8147
